# %% [markdown]
# <a href="https://colab.research.google.com/github/ybeth-gonzaga/Taylor-Swift-Spotify-Analysis/blob/main/001_initial_check.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Import File
charts = pd.read_csv("/content/ph_spotify_daily_charts.csv")
charts.head()
# Out:
#          date  position                track_id            track_name  \
# 0  2017-01-01         1  0kN8xEmgMW9mh7UmDYHlJP  Versace on the Floor
# 1  2017-01-01         2  5uCax9HTNlzGybIStD3vDh  Say You Won't Let Go
# 2  2017-01-01         3  7BKLCZ1jbUBVqRi2FVlTVw                Closer
# 3  2017-01-01         4  2rizacJSyD9S1IQUxUxnsK           All We Know
# 4  2017-01-01         5  5MFzQMkrl1FOOng9tq6R9r      Don't Wanna Know
#
#              artist  streams
# 0        Bruno Mars   185236
# 1      James Arthur   180552
# 2  The Chainsmokers   158720
# 3  The Chainsmokers   130874
# 4          Maroon 5   129656
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['position'].plot(kind='hist', bins=20, title='position')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
charts.shape
# There are 495,798 rows and 6 columns
# Out:
# (495798, 6)

# %%
# Show the datatypes of each column
charts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495798 entries, 0 to 495797
# Data columns (total 6 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   date        495798 non-null  object
#  1   position    495798 non-null  int64
#  2   track_id    495798 non-null  object
#  3   track_name  495788 non-null  object
#  4   artist      495788 non-null  object
#  5   streams     495798 non-null  int64
# dtypes: int64(2), object(4)
# memory usage: 22.7+ MB

# %%
# Getting the date range
smallest_date = charts['date'].min()
largest_date = charts['date'].max()
print('The data ranges from',smallest_date,'to',largest_date)
# Out:
# The data ranges from 2017-01-01 to 2023-10-15

# %%
# Get the subset
charts_taylor_swift = charts[charts.artist == "Taylor Swift"]
charts_taylor_swift.head()
# Out:
#              date  position                track_id      track_name  \
# 31292  2017-06-09        93  0ug5NqcwcFR2xrfTkc7k8e           Style
# 31294  2017-06-09        95  1u8c2t2Cy7UBoG4ArRcF5g     Blank Space
# 31341  2017-06-09       142  0cqRj7pUJDkTCEsJkx8snD    Shake It Off
# 31346  2017-06-09       147  1vrd6UOGamcKNGnSHJQlSt      Love Story
# 31348  2017-06-09       149  3fVnlF4pGqWI9flVENcT28  Wildest Dreams
#
#              artist  streams
# 31292  Taylor Swift    30552
# 31294  Taylor Swift    29818
# 31341  Taylor Swift    24406
# 31346  Taylor Swift    23608
# 31348  Taylor Swift    23323
