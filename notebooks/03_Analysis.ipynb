# %% [markdown]
# <a href="https://colab.research.google.com/github/ybeth-gonzaga/Taylor-Swift-Spotify-Analysis/blob/main/03_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import re
import seaborn as sns
import pandas as pd
import numpy as np

# %%
# Import File
df = pd.read_csv("https://raw.githubusercontent.com/ybeth-gonzaga/Taylor-Swift-Spotify-Analysis/main/ph_spotify_daily_charts_ts_summary.csv")
df.head()
# Out:
#    Unnamed: 0        date  total_streams  stream_percent_change  total_count  \
# 0           0  2017-01-01              0                    0.0            0
# 1           1  2017-01-02              0                    0.0            0
# 2           2  2017-01-03              0                    0.0            0
# 3           3  2017-01-04              0                    0.0            0
# 4           4  2017-01-05              0                    0.0            0
#
#    count_percent_change  highest_rank  top_rank_diff
# 0                   0.0           NaN            0.0
# 1                   0.0           NaN            0.0
# 2                   0.0           NaN            0.0
# 3                   0.0           NaN            0.0
# 4                   0.0           NaN            0.0

# %% [markdown]
# # Count Analysis

# %%
# Sort the 30 highest number of charting songs by date
df_count_ranked.sort_values(by='total_count', ascending=False).head(30).sort_values(by='date')
# Out:
#       Unnamed: 0        date  total_streams  stream_percent_change  \
# 1772        1772  2021-11-12        8476377            1053.848259
# 1773        1773  2021-11-13        6443379             -23.984280
# 1774        1774  2021-11-14        5136173             -20.287585
# 1775        1775  2021-11-15        5125739              -0.203147
# 1776        1776  2021-11-16        4448454             -13.213412
# 1777        1777  2021-11-17        4002500             -10.024921
# 1778        1778  2021-11-18        3787237              -5.378214
# 1779        1779  2021-11-19        3287671             -13.190777
# 1780        1780  2021-11-20        2654654             -19.254268
# 2378        2378  2023-07-07       20159438             294.685730
# 2379        2379  2023-07-08       14318720             -28.972623
# 2380        2380  2023-07-09       12270440             -14.304910
# 2381        2381  2023-07-10       11663197              -4.948828
# ...

# %% [markdown]
# # Percent Change in Streams Analysis

# %%
df.sort_values(by='stream_percent_change', ascending=False)
# Out:
#      Unnamed: 0        date  total_streams  stream_percent_change  \
# 178         178  2017-07-01          16862                    inf
# 715         715  2018-12-20          22088                    inf
# 842         842  2019-04-26         433059                    inf
# 722         722  2018-12-27          21206                    inf
# 708         708  2018-12-13          23801                    inf
# ..          ...         ...            ...                    ...
# 424         424  2018-03-04              0                 -100.0
# 749         749  2019-01-23              0                 -100.0
# 710         710  2018-12-15              0                 -100.0
# 745         745  2019-01-19              0                 -100.0
# 541         541  2018-06-29              0                 -100.0
#
#      total_count  count_percent_change  highest_rank  top_rank_diff
# 178            1                   inf         200.0            0.0
# ...

# %%
# There exists inf values due to limitations that only top 200 songs have the recorded stream
# To fix that, exchange inf to NaN

# %%
# Replace 'inf' values with NaN
df['stream_percent_change'] = df['stream_percent_change'].replace(np.inf, np.nan)

# Convert the column to numeric data type
df['stream_percent_change'] = pd.to_numeric(df['stream_percent_change'])

# check if inf is gone
df['stream_percent_change'].value_counts()
# Out:
# stream_percent_change
#  0.000000      493
# -100.000000     10
#  1.150611        1
# -0.483002        1
# -4.299148        1
#               ...
#  7.659308        1
# -1.158338        1
# -11.221965       1
# -3.137291        1
#  5.683393        1
# Name: count, Length: 1967, dtype: int64

# %%
streams_df = df.sort_values(by='stream_percent_change', ascending=False)
streams_df.head(30)
# Out:
#       Unnamed: 0        date  total_streams  stream_percent_change  \
# 1297        1297  2020-07-24        5019956            3173.848763
# 1437        1437  2020-12-11        2989691            1425.158016
# 1772        1772  2021-11-12        8476377            1053.848259
# 2119        2119  2022-10-21       12926945             955.448643
# 1556        1556  2021-04-09        4476141             924.487829
# 2084        2084  2022-09-16         971098             836.196591
# 961          961  2019-08-23        2188177             501.192121
# 1500        1500  2021-02-12         880686             482.660818
# 1716        1716  2021-09-17         324344             315.484730
# 2378        2378  2023-07-07       20159438             294.685730
# 1627        1627  2021-06-19         327582             234.584861
# 1436        1436  2020-12-10         196025             214.651921
# 1699        1699  2021-08-31          98308             201.873119
# ...

# %%
df.to_csv('streams_analysis.csv', index=False)
